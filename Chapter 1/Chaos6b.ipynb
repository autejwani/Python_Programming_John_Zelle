# %% [markdown]
# <a href="https://colab.research.google.com/github/autejwani/Python_Programming_John_Zelle/blob/master/Chapter%201/Chaos6b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# File: chaos6b.py
# A simple program illustrating chaotic behavior.  It prints out 100 values.
# Solution to Programming Exercise 6a of Chapter 1 of Python Programming:
# An Introduction to Computer Science, 3rd Edition, Franklin, Beedle, and 
# Associates

def main():
    print("This program illustrates a chaotic function")
    x = eval(input("Enter a number between 0 and 1: "))
    for i in range(100):
        x = 3.9 * (x - x * x)
        print(x)

main()
# Out:
# This program illustrates a chaotic function
# Enter a number between 0 and 1: 0.2
# 0.624
# 0.9150336
# 0.30321373239705607
# 0.8239731430433199
# 0.5656614700878669
# 0.9581854282490107
# 0.15625784202705556
# 0.5141811824452029
# 0.9742156868513779
# 0.09796598114189603
# 0.34463772595512665
# 0.8808639988340621
# 0.4092761961292976
# 0.9428998465037982
# 0.2099749312709568
# 0.6469532920839837
# 0.8907784467881497
# 0.379439601550781
# 0.9183142422704856
# 0.2925514593833107
# 0.8071639016844225
# 0.6070363162578094
# 0.9303185853076369
# 0.25282106904145285
# 0.7367200467517402
# 0.7564581159168303
# 0.7184940156435197
# 0.7888154239990807
# 0.6496840383549018
# 0.8876192857808963
# 0.38903002823376065
# 0.9269740949281801
# 0.2640031768150197
# 0.7577914478417288
# 0.7158199207366943
# 0.7933448710715074
# 0.6394002678025589
# 0.899213504812642
# 0.3534514525433061
# 0.8912417406294992
# 0.37802661151787875
# 0.9169777207585391
# 0.29690536352495384
# 0.8141350176767685
# ...
